# %% [markdown]
# # GRIP : The Sparks Foundation

# %% [markdown]
# # Data Science and Business Analytics Intern

# %% [markdown]
# #  Author : Palak Jain

# %% [markdown]
# # Task 4 : Exploratory Data Analysis on Global Terrorism

# %% [markdown]
# ### Step 1 - Importing the libraries

# %%
### Importing the libraries ###
 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings as wg
wg.filterwarnings('ignore')

# %%
data_info = pd.read_csv(r"C:\Users\Vaibhav\Downloads\Global Terrorism - START data.zip",encoding = 'latin1',low_memory = False)
data_info.head(10)
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
# 5  197001010002   1970       1     1        NaN         0        NaN      217
# 6  197001020001   1970       1     2        NaN         0        NaN      218
# 7  197001020002   1970       1     2        NaN         0        NaN      217
# 8  197001020003   1970       1     2        NaN         0        NaN      217
# 9  197001030001   1970       1     3        NaN         0        NaN      217
#
#           country_txt  region  ...  \
# 0  Dominican Republic       2  ...
# 1              Mexico       1  ...
# ...

# %%
data_info.shape
# Out:
# (181691, 135)

# %%
data_info.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
data_info.tail(5)
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ... addnotes  \
# 181686      182      Somalia      11  ...      NaN
# 181687      200        Syria      10  ...      NaN
# 181688      160  Philippines       5  ...      NaN
# 181689       92        India       6  ...      NaN
# 181690      160  Philippines       5  ...      NaN
#
#                                                    scite1  \
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# ...

# %%
data_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
data_info.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
## correlation matrix and heatmap ##
corr = data_info.corr()
corr
# Out:
#             eventid     iyear    imonth      iday  extended   country  \
# eventid    1.000000  0.999996  0.002706  0.018336  0.091761 -0.135039
# iyear      0.999996  1.000000  0.000139  0.018254  0.091754 -0.135023
# imonth     0.002706  0.000139  1.000000  0.005497 -0.000468 -0.006305
# iday       0.018336  0.018254  0.005497  1.000000 -0.004700  0.003468
# extended   0.091761  0.091754 -0.000468 -0.004700  1.000000 -0.020466
# ...             ...       ...       ...       ...       ...       ...
# nreleased -0.181612 -0.181556 -0.011535  0.001765 -0.192155 -0.044331
# INT_LOG   -0.143600 -0.143601 -0.002302 -0.001540  0.071768  0.069904
# INT_IDEO  -0.133252 -0.133253 -0.002034 -0.001621  0.075147  0.067564
# INT_MISC  -0.077852 -0.077847 -0.002554 -0.002027  0.027335  0.207281
# INT_ANY   -0.175605 -0.175596 -0.006336 -0.001199  0.080767  0.153118
#
#              region  latitude  longitude  specificity  ...  ransomamt  \
# ...

# %% [markdown]
# ### Step 2 - Data Visualizations

# %%
plt.figure(figsize = (25,17))
small = data_info.drop (['latitude','longitude','specificity'],axis=1)
small = small.iloc[15:,15:]
smallcorr = small.corr()
sns.heatmap(smallcorr, annot = True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(20,4))
sns.countplot(data_info['iyear'])
plt.title('observation in number of events with years ')
# Out:
# Text(0.5, 1.0, 'observation in number of events with years ')

# %%
sns.countplot(data_info['extended'])
plt.title('Incidents extended more than 24 hours a not')
# Out:
# Text(0.5, 1.0, 'Incidents extended more than 24 hours a not')

# %%
f = plt.figure(figsize=[15,3])
f.add_subplot(121)
#the attacks with political, economical ,social, religious cause
sns.countplot(data_info['crit1'])
plt.title('Inclusions criteria of attack')

f.add_subplot(122)
sns.countplot(data_info['multiple'])
plt.title('Number of attacks which were part of multiple incidents')
# Out:
# Text(0.5, 1.0, 'Number of attacks which were part of multiple incidents')

# %%
len(data_info['country_txt'])
# Out:
# 181691

# %%
f = plt.figure(figsize=[25,19])
sns.countplot(data_info['country_txt'].iloc[:100])
# Out:
# <AxesSubplot:xlabel='country_txt', ylabel='count'>

# %%
len(data_info[data_info['country_txt']=='United States'])
# Out:
# 2836

# %%
data_info['country_txt'].value_counts()
# Out:
# Iraq                   24636
# Pakistan               14368
# Afghanistan            12731
# India                  11960
# Colombia                8306
#                        ...
# International              1
# Wallis and Futuna          1
# South Vietnam              1
# Andorra                    1
# Antigua and Barbuda        1
# Name: country_txt, Length: 205, dtype: int64

# %%
f = plt.figure(figsize=[35,10])
sns.countplot(data_info['country_txt'][:181691])
# Out:
# <AxesSubplot:xlabel='country_txt', ylabel='count'>

# %%
data_info['region'].unique()
# 1- North America 
# 2- Central America & Caribbean
# 3- South America
# 4- East Asia
# 5- Southeast Asia
# 6- South Asia
# 7- Central Asia
# 8- Western Europe
# 9- Eastern Europe
# 10- Middle East & North Africa
# 11- Sub-Saharan Africa
# 12- Australasia & Oceania
# Out:
# array([ 2,  1,  5,  8,  4,  3,  9, 11, 10, 12,  6,  7], dtype=int64)

# %%
sns.countplot(data_info['region'])
# Out:
# <AxesSubplot:xlabel='region', ylabel='count'>

# %%
data_info['attacktype1'].unique()
# 1 Assassination
# 2 Armed Assault
# 3 Bombing/Explosion
# 4 Hijacking
# 5 Hostage Taking(Barricode Incident)
# 6 Hostage Taking(Kidnapping) 
# 7 Facility/Infrastructure Attack
# 8 Unarmed Assault
# 9 Unknown
sns.countplot(data_info['attacktype1'])
# Out:
# <AxesSubplot:xlabel='attacktype1', ylabel='count'>

# %%
sns.countplot(data_info['targtype1'])
plt.title('Targets of attack')
# Out:
# Text(0.5, 1.0, 'Targets of attack')

# %%
crosstab = pd.crosstab(data_info.success,data_info.iyear)
crosstab
# Out:
# iyear    1970  1971  1972  1973  1974  1975  1976  1977  1978  1979  ...  \
# success                                                              ...
# 0         102    51   116    40    36    35    62   128   115   254  ...
# 1         549   420   452   433   545   705   861  1191  1411  2408  ...
#
# iyear    2008  2009  2010  2011  2012   2013   2014   2015   2016  2017
# success
# 0         403   291   441   470   922   1552   1888   2289   2612  2248
# 1        4402  4430  4385  4606  7600  10484  15015  12676  10975  8652
#
# [2 rows x 47 columns]

# %%
# weapontype of a terrorist attack 
# 1 Biological
# 2 chemical
# 3 Radiological
# 4 Nuclear
# 5 Firearms
# 6 Explosives
# 7 Fake Weapons
# 8 Incendiary
# 9 Melee
# 10 Vehicle
# 11 Sabotage Equipment
# 12 Other
# 13 Unknown
data_info['weaptype1'].unique()
# Out:
# array([13,  6,  8,  5,  2,  9, 11, 10,  7,  3, 12,  1], dtype=int64)

# %%
sns.countplot(data_info['weaptype1'])
plt.title('Weapon for attack')
# Out:
# Text(0.5, 1.0, 'Weapon for attack')

# %%
data_info['nperps'].max()
# Out:
# 25000.0

# %%
data_info[data_info['nperps']==data_info['nperps'].max()].set_index('nperps') 
# the attack on Bangladesh has max number of perpetratos
# Out:
#               eventid  iyear  imonth  iday approxdate  extended resolution  \
# nperps
# 25000.0  199409100003   1994       9    10        NaN         0        NaN
#
#          country country_txt  region  ... addnotes scite1 scite2  scite3  \
# nperps                                ...
# 25000.0       19  Bangladesh       6  ...      NaN    NaN    NaN     NaN
#
#          dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# nperps
# 25000.0      PGIS       -9        -9        0      -9      NaN
#
# [1 rows x 134 columns]

# %%
data_info[data_info['nperps']==data_info['nperps'].min()].set_index('nperps') 
# atleast 11 or unknown or if the prepatrators not reported then -99.0 is given to that row
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# nperps
# -99.0   197001010002   1970       1     1        NaN         0        NaN
# -99.0   197001020002   1970       1     2        NaN         0        NaN
# -99.0   197001060001   1970       1     6        NaN         0        NaN
# -99.0   197001090001   1970       1     9        NaN         0        NaN
# -99.0   197001090002   1970       1     9        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# -99.0   201712310022   2017      12    31        NaN         0        NaN
# -99.0   201712310029   2017      12    31        NaN         0        NaN
# -99.0   201712310030   2017      12    31        NaN         0        NaN
# -99.0   201712310031   2017      12    31        NaN         0        NaN
# -99.0   201712310032   2017      12    31        NaN         0        NaN
#
#         country    country_txt  region  ...  \
# ...

# %%
sns.countplot(data_info['claimed'])
plt.title('Claims of responsibility of attack taken or not or unknown')
# claims are not taken mostly
# more than 80000, the responsibility of attack was not claimed
# Out:
# Text(0.5, 1.0, 'Claims of responsibility of attack taken or not or unknown')

# %%
data_info[data_info['country_txt']=='India']
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 1186    197202220004   1972       2    22        NaN         0        NaN
# 2764    197501190004   1975       1     2        NaN         0        NaN
# 3857    197605260001   1976       5    26        NaN         0        NaN
# 5327    197709280004   1977       9    28        NaN         0        NaN
# 7337    197901130004   1979       1    13        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181663  201712300021   2017      12    30        NaN         0        NaN
# 181665  201712300023   2017      12    30        NaN         0        NaN
# 181672  201712310005   2017      12    31        NaN         0        NaN
# 181684  201712310019   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
#
#         country country_txt  region  ...  \
# ...

# %%
data_info[data_info['iyear']>2000].shape
# these many events took place after 2000
# Out:
# (110041, 135)

# %%
events_after_2000 = data_info[data_info['iyear']>2000]
plt.figure(figsize=(10,8))
sns.countplot(events_after_2000['iyear'])
plt.title('Number of series of events after year 2000')
# Out:
# Text(0.5, 1.0, 'Number of series of events after year 2000')

# %%
sns.relplot(data=data_info, x="nkill", y="iyear", hue="nwound")
plt.title('Observation of number of killed and wounded during attack')
# Out:
# Text(0.5, 1.0, 'Observation of number of killed and wounded during attack')

# %%
#1 = Attempted Rescue
#2 = Hostage(s) released by perpetrators
#3 = Hostage(s) escaped (not during rescue attempt)
#4 = Hostage(s) killed (not during rescue attempt)
#5 = Successful Rescue
#6 = Combination
#7 = Unknown
sns.countplot(data_info['hostkidoutcome'])
plt.title('Observations of number of hostages- rescued or not')
# Out:
# Text(0.5, 1.0, 'Observations of number of hostages- rescued or not')
